# %% [markdown]
# ## Background
#
# From my experience, the performance of neural network is very sensitive to hyper-parameter settings. Thus, it is very crucial to optimize the hyper-parameters of the neural network.
#
# This notebook shows the examples of using hyperopt to optimize the neural network built from Pytorch.
#
# **Features included:**
#
# 1. With implementation of early stopping.
# 2. With implementation of hyper-parameter tuning with hyperopt.

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
import random

import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import f1_score, confusion_matrix

from hyperopt import hp, tpe, fmin, Trials, space_eval
from functools import partial

from hpsklearn import HyperoptEstimator
from hpsklearn import any_classifier
from hpsklearn import any_preprocessing
# Out:
# WARN: OMP_NUM_THREADS=None =>
# ... If you are using openblas if you are using openblas set OMP_NUM_THREADS=1 or risk subprocess calls hanging indefinitely

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import random_split
from torch import Generator
from torch import Tensor
from torch.nn import Linear
from torch.nn import ReLU
from torch.nn import Sigmoid
from torch.nn import Module
from torch.optim import SGD
from torch.nn import BCELoss
from torch.nn.init import kaiming_uniform_
from torch.nn.init import xavier_uniform_

import random

# %%
# set device to CUDA if available, else to CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# Device: cuda

# %% [markdown]
# ## Hyper-parameter Settings

# %%
TEST_SIZE = 0.3
NUM_FOLDS = 5
RANDOM_STATE = 0

# %%
random.seed(RANDOM_STATE)
torch.manual_seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
torch.use_deterministic_algorithms(True)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Pytorch NN Definition

# %%
# dataset definition
class CSVDataset(Dataset):
    # load the dataset
    def __init__(self, path):
        # load the csv file as a dataframe
        df = read_csv(path, header=None)
        # store the inputs and outputs
        self.X = df.values[:, :-1]
        self.y = df.values[:, -1]
        # ensure input data is floats
        self.X = self.X.astype('float32')
        # label encode target and ensure the values are floats
        self.y = LabelEncoder().fit_transform(self.y)
        self.y = self.y.astype('float32')
        self.y = self.y.reshape((len(self.y), 1))
 
    # number of rows in the dataset
    def __len__(self):
        return len(self.X)
 
    # get a row at an index
    def __getitem__(self, idx):
        return [self.X[idx], self.y[idx]]
 
    # get indexes for train and test rows
    def get_splits(self, n_test, random_state):
        # determine sizes
        test_size = round(n_test * len(self.X))
        train_size = len(self.X) - test_size
        # calculate the split
        return random_split(self, [train_size, test_size], generator=Generator().manual_seed(random_state))

# %%
# model definition
class MLP(Module):
    # define model elements
    def __init__(self, n_inputs, hidden_layer1, hidden_layer2,):
        super(MLP, self).__init__()
        # input to first hidden layer
        self.hidden1 = Linear(n_inputs, hidden_layer1)
        kaiming_uniform_(self.hidden1.weight, nonlinearity='relu')
        self.act1 = ReLU()
        # second hidden layer
        self.hidden2 = Linear(hidden_layer1, hidden_layer2)
        kaiming_uniform_(self.hidden2.weight, nonlinearity='relu')
        self.act2 = ReLU()
        # third hidden layer and output
        self.hidden3 = Linear(hidden_layer2, 1)
        xavier_uniform_(self.hidden3.weight)
        self.act3 = Sigmoid() # self.act3 = Softmax(dim=1) for multi-class classification
 
    # forward propagate input
    def forward(self, X):
        # input to first hidden layer
        X = self.hidden1(X)
        X = self.act1(X)
         # second hidden layer
        X = self.hidden2(X)
        X = self.act2(X)
        # third hidden layer and output
        X = self.hidden3(X)
        X = self.act3(X)
        return X

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %%
# prepare the dataset
def prepare_data(path):
    # load the dataset
    dataset = CSVDataset(path)
    # calculate split
    train, test = dataset.get_splits(n_test=TEST_SIZE, random_state=RANDOM_STATE)
    # prepare data loaders
    train_dl = DataLoader(train, batch_size=32, worker_init_fn=seed_worker, shuffle=True)
    test_dl = DataLoader(test, batch_size=1024, worker_init_fn=seed_worker, shuffle=False)
    return train_dl, test_dl

# %%
## for cross validation
def reset_weights(m):
    '''
    Try resetting model weights to avoid
    weight leakage.
    '''
    for layer in m.children():
        if hasattr(layer, 'reset_parameters'):
            # print(f'Reset trainable parameters of layer = {layer}')
            layer.reset_parameters()

# %%
# train the model
def train_model(train_dl, valid_dl, PARA, epochs=100, patience=10, early_stopping=False, cross_valid=False):
    
    ######################################
    # variables declaration for hyperopt #
    ######################################
    
    LR = PARA['lr']
    MOMENTUM = PARA['momentum']
    HIDDEN_LYR1 = PARA['hidden_layer1']
    HIDDEN_LYR2 = PARA['hidden_layer2']
    
    ###########################################
    # variables declaration for early stopping#
    ###########################################
    
    # to track the training loss as the model trains
    train_losses = []
    # to track the validation loss as the model trains
    valid_losses = []
    # to track the average training loss per epoch as the model trains
    avg_train_losses = []
    # to track the average validation loss per epoch as the model trains
    avg_valid_losses = []
    
    # initialize for early stopping
    epochs_no_improve = 0
    min_val_loss = np.Inf
    early_stop_detected = False
    
    ###############################
    # model related implementation#
    ###############################
    
    # define the model
    model = MLP(60, HIDDEN_LYR1, HIDDEN_LYR2)
    if cross_valid:
        model.apply(reset_weights)
        
    # define the optimization
    criterion = BCELoss() # CrossEntropyLoss() for multi-class classification
    optimizer = SGD(model.parameters(), lr=LR, momentum=MOMENTUM)
    
    # enumerate epochs
    for epoch in range(1, epochs+1):
        
        # prepare model for training
        model.train() 
        # enumerate mini batches
        for i, (inputs, targets) in enumerate(train_dl):
            # clear the gradients
            optimizer.zero_grad()
            # compute the model output
            y_pred_train = model(inputs)
            # calculate loss
            loss = criterion(y_pred_train, targets)
            # credit assignment
            loss.backward()
            # update model weights
            optimizer.step()
            # record training loss
            train_losses.append(loss.item())
            
        # print training/validation statistics 
        # calculate average loss over an epoch 
        train_loss = np.average(train_losses)
        avg_train_losses.append(train_loss)
        
        # clear lists to track next epoch
        train_losses = []
        
        epoch_len = len(str(epochs))
        
        if valid_dl is None:
        
            print_msg = (f'[{epoch:>{epoch_len}}/{epochs:>{epoch_len}}] ' +
                             f'train_loss: {train_loss:.5f} ')
            
            print(print_msg)
        
        # process valid set if it is available
        else:
            # prepare model for evaluation
            model.eval() 

            for inputs, targets in valid_dl:
                # forward pass: compute predicted outputs by passing inputs to the model
                y_pred_valid = model(inputs)
                # calculate the loss
                loss = criterion(y_pred_valid, targets)
                # record validation loss
                valid_losses.append(loss.item())

            # print training/validation statistics 
            # calculate average loss over an epoch            
            valid_loss = np.average(valid_losses)
            avg_valid_losses.append(valid_loss)

            print_msg = (f'[{epoch:>{epoch_len}}/{epochs:>{epoch_len}}] ' +
                         f'train_loss: {train_loss:.5f} ' +
                         f'valid_loss: {valid_loss:.5f}')

            # print(print_msg)

            # clear lists to track next epoch
            valid_losses = []

            if early_stopping:

                # early_stopping needs the validation loss to check if it has decresed
                if valid_loss < min_val_loss:
                    epochs_no_improve = 0
                    min_val_loss = valid_loss
                else:
                    epochs_no_improve += 1

                if epoch > 5 and epochs_no_improve==patience:
                    early_stop_detected = True
                    break
                
    #     if early_stopping:
    #         if early_stop_detected:
    #             print(f'  Early stopping at epoch: {epoch}!' )
    #             print(f'  Stopped with valid loss={valid_loss:.5f}')
    #         else:
    #             print(f'  No early stopping. Finish training until epoch: {epoch}!' )
    #             print(f'  Stopped with valid loss={valid_loss:.5f}')    

    return model, avg_train_losses, avg_valid_losses

# %%
# evaluate the model
def evaluate_model(model, test_dl):
    predictions, actuals = list(), list()
    # prep model for evaluation
    model.eval() 
    for i, (inputs, targets) in enumerate(test_dl):
        # evaluate the model on the test set
        y_proba = model(inputs)
        # retrieve numpy array
        y_proba = y_proba.detach().numpy()
        # round to class values
        y_pred = y_proba.round()
        # extract true label
        y_true = targets.numpy()
        y_true = y_true.reshape((len(y_true), 1))
        # store
        predictions.append(y_pred)
        actuals.append(y_true)
    predictions, actuals = np.vstack(predictions), np.vstack(actuals)
    # calculate f1-score
    f1 = f1_score(actuals, predictions)
    return f1, actuals, predictions

# %%
# make a class prediction for one row of data
def predict(row, model):
    # make prediction
    y_proba = model(row)
    # retrieve numpy array
    y_proba = y_proba.detach().numpy()
    y_pred = y_proba.round() # np.argmax(y_proba) for multi-class classification
    return y_proba, y_pred

# %%
def objective(params):
    
    print ('Params testing: ', params)
    print ('\n ')
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=NUM_FOLDS, shuffle=True)
    scores = []

    # K-fold Cross Validation model evaluation
    for fold, (train_ids, valid_ids) in enumerate(kfold.split(train_dl.dataset)):

        random.shuffle(train_ids)
        
        # Sample elements randomly from a given list of ids, no replacement.
        train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
        valid_subsampler = torch.utils.data.SubsetRandomSampler(valid_ids)

        # Define data loaders for training and testing data in this fold
        trainloader = torch.utils.data.DataLoader(
                          train_dl.dataset, 
                          batch_size=10, sampler=train_subsampler)
        validloader = torch.utils.data.DataLoader(
                          train_dl.dataset,
                          batch_size=10, sampler=valid_subsampler)
    
        # Train Model
        model, avg_train_losses, avg_valid_losses = train_model(train_dl=trainloader, 
                                                                valid_dl=validloader, 
                                                                PARA=params,
                                                                early_stopping=True, 
                                                                cross_valid=True)
     
        #predict the test set 
        f1, _, _ = evaluate_model(model, validloader)
        # print('F1 score: %.3f' % f1)
        scores.append(f1)
        
    mean = round(sum(scores)/len(scores), 3)
    print('Mean F1 score from cross validation: %.3f' % mean)
    
    return -mean

# %%
# prepare the data
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv'
train_dl, test_dl = prepare_data(path)
print(len(train_dl.dataset), len(test_dl.dataset))

# hyper-parameter optimization with hyperopt
# define space
nn_space = {'lr' : hp.choice('lr', np.logspace(-2, -4, 3)),
            'momentum': hp.choice('momentum', [0.3,0.5,0.8,0.9]),
            'hidden_layer1': hp.choice('hidden_layer1', [10,20,30]),
            'hidden_layer2': hp.choice('hidden_layer2', [5,8,10,20]),
           }

trials = Trials()

# Run Hyper Optimization
para_best = fmin(
    fn=objective,
    space=nn_space,
    algo=tpe.suggest,
    return_argmin=False,
    timeout=None,
    verbose=True,
    trials=trials,
    max_evals=100,  # Max Number of Iterations
    rstate=np.random.RandomState(0)
)

print("Best Parameters")
print(para_best)
# Out:
# 146 62
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.292
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.425
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.324
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.414
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.432
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.406
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.525
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.627
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.626
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.417
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.564
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.117
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.506
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.387
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.259
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.412
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.248
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.677
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.000
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.653
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.323
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.412
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.507
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.406
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.601
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.614
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.509
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.210
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.597
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 8, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.518
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.713
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.377
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.700
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.210
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.604
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.667
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.531
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.598
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.587
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.403
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.660
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.484
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 10, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.680
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.560
# Params testing:
# {'hidden_layer1': 10, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.560
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.747
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.416
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.423
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.753
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.400
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.584
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.538
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.235
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.534
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.598
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.489
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.259
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.660
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.642
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.448
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.602
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.124
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.726
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.538
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.770
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.612
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.652
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.571
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.621
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.730
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.668
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.727
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.483
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.536
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.636
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 8, 'lr': 0.001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.546
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.148
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.720
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.606
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.416
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 8, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.679
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.540
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.0001, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.247
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.523
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.663
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 20, 'lr': 0.001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.671
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.562
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 8, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.550
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.701
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.640
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.544
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.512
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.699
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 8, 'lr': 0.0001, 'momentum': 0.3}
# Mean F1 score from cross validation: 0.267
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.602
# Params testing:
# {'hidden_layer1': 20, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.5}
# Mean F1 score from cross validation: 0.606
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.01, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.753
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 5, 'lr': 0.001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.405
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 20, 'lr': 0.01, 'momentum': 0.9}
# Mean F1 score from cross validation: 0.671
# Params testing:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.0001, 'momentum': 0.8}
# Mean F1 score from cross validation: 0.257
# 100%|██████████| 100/100 [03:02<00:00,  1.83s/trial, best loss: -0.77]
# Best Parameters
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}

# %%
para_best
# Out:
# {'hidden_layer1': 30, 'hidden_layer2': 10, 'lr': 0.01, 'momentum': 0.8}

# %%
# train the model
model, avg_train_losses, avg_valid_losses = train_model(train_dl=train_dl, 
                                                        valid_dl=None, 
                                                        PARA=para_best,
                                                        early_stopping=True)
# evaluate the model
F1_test, actuals_test, predictions_test = evaluate_model(model, test_dl)

print(f"Test F1-Score: {round(F1_test, 3)}")

# Show summary of performance
cf_matrix = confusion_matrix(actuals_test, predictions_test)

plt.figure(dpi=150, figsize=(4, 3))
sns.heatmap(cf_matrix, annot=True)
plt.show()

# make a single prediction (expect class=1)
for inputs, targets in test_dl:  
    sample_X_test = inputs[0] 
    sample_y_test = targets[0]
y_proba, y_pred = predict(sample_X_test, model)
print('Predicted class=%d (y_proba=%.3f) vs (Actual class=%d)' % (y_pred, y_proba, sample_y_test.numpy()[0]))
# Out:
# [  1/100] train_loss: 0.79370
# [  2/100] train_loss: 0.75626
# [  3/100] train_loss: 0.72902
# [  4/100] train_loss: 0.71812
# [  5/100] train_loss: 0.71675
# [  6/100] train_loss: 0.70367
# [  7/100] train_loss: 0.70003
# [  8/100] train_loss: 0.69429
# [  9/100] train_loss: 0.68862
# [ 10/100] train_loss: 0.68623
# [ 11/100] train_loss: 0.67730
# [ 12/100] train_loss: 0.67444
# [ 13/100] train_loss: 0.67518
# [ 14/100] train_loss: 0.67099
# [ 15/100] train_loss: 0.66728
# [ 16/100] train_loss: 0.66209
# [ 17/100] train_loss: 0.66505
# [ 18/100] train_loss: 0.65298
# [ 19/100] train_loss: 0.64972
# [ 20/100] train_loss: 0.65029
# [ 21/100] train_loss: 0.64511
# [ 22/100] train_loss: 0.64320
# [ 23/100] train_loss: 0.64031
# [ 24/100] train_loss: 0.63046
# [ 25/100] train_loss: 0.62888
# [ 26/100] train_loss: 0.62277
# [ 27/100] train_loss: 0.61965
# [ 28/100] train_loss: 0.62199
# [ 29/100] train_loss: 0.61912
# [ 30/100] train_loss: 0.60875
# [ 31/100] train_loss: 0.60452
# [ 32/100] train_loss: 0.60859
# [ 33/100] train_loss: 0.59742
# [ 34/100] train_loss: 0.59784
# [ 35/100] train_loss: 0.59123
# [ 36/100] train_loss: 0.58805
# [ 37/100] train_loss: 0.59224
# [ 38/100] train_loss: 0.57333
# [ 39/100] train_loss: 0.56906
# [ 40/100] train_loss: 0.57911
# [ 41/100] train_loss: 0.57192
# [ 42/100] train_loss: 0.56296
# [ 43/100] train_loss: 0.55755
# [ 44/100] train_loss: 0.55388
# [ 45/100] train_loss: 0.55075
# [ 46/100] train_loss: 0.54647
# [ 47/100] train_loss: 0.54265
# [ 48/100] train_loss: 0.53388
# [ 49/100] train_loss: 0.53776
# [ 50/100] train_loss: 0.53288
# [ 51/100] train_loss: 0.52042
# [ 52/100] train_loss: 0.51329
# [ 53/100] train_loss: 0.51932
# [ 54/100] train_loss: 0.50101
# [ 55/100] train_loss: 0.49765
# [ 56/100] train_loss: 0.49746
# [ 57/100] train_loss: 0.50484
# [ 58/100] train_loss: 0.49036
# [ 59/100] train_loss: 0.50130
# [ 60/100] train_loss: 0.48008
# [ 61/100] train_loss: 0.48588
# [ 62/100] train_loss: 0.48557
# [ 63/100] train_loss: 0.46610
# [ 64/100] train_loss: 0.48043
# [ 65/100] train_loss: 0.46578
# [ 66/100] train_loss: 0.45538
# [ 67/100] train_loss: 0.46009
# [ 68/100] train_loss: 0.45549
# [ 69/100] train_loss: 0.46206
# [ 70/100] train_loss: 0.46651
# [ 71/100] train_loss: 0.45178
# [ 72/100] train_loss: 0.46830
# [ 73/100] train_loss: 0.46477
# [ 74/100] train_loss: 0.46399
# [ 75/100] train_loss: 0.43612
# [ 76/100] train_loss: 0.44496
# [ 77/100] train_loss: 0.42413
# [ 78/100] train_loss: 0.43324
# [ 79/100] train_loss: 0.42060
# [ 80/100] train_loss: 0.42523
# [ 81/100] train_loss: 0.40999
# [ 82/100] train_loss: 0.40961
# [ 83/100] train_loss: 0.41995
# [ 84/100] train_loss: 0.41429
# [ 85/100] train_loss: 0.40996
# [ 86/100] train_loss: 0.41166
# [ 87/100] train_loss: 0.41909
# [ 88/100] train_loss: 0.41514
# [ 89/100] train_loss: 0.41059
# [ 90/100] train_loss: 0.40678
# [ 91/100] train_loss: 0.40827
# [ 92/100] train_loss: 0.39186
# [ 93/100] train_loss: 0.40695
# [ 94/100] train_loss: 0.38627
# [ 95/100] train_loss: 0.39478
# [ 96/100] train_loss: 0.39241
# [ 97/100] train_loss: 0.37233
# [ 98/100] train_loss: 0.37740
# [ 99/100] train_loss: 0.40344
# [100/100] train_loss: 0.38065
# Test F1-Score: 0.773
# Predicted class=1 (y_proba=0.951) vs (Actual class=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Reference
#
# 1. https://machinelearningmastery.com/pytorch-tutorial-develop-deep-learning-models/
# 2. https://www.machinecurve.com/index.php/2021/02/03/how-to-use-k-fold-cross-validation-with-pytorch/
# 3. https://github.com/Bjarten/early-stopping-pytorch/blob/master/MNIST_Early_Stopping_example.ipynb
